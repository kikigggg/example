# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Keertana Ganesan**

# %% [markdown]
# *I'm interested in data science as I'm looking to change jobs and transition from academia to a commerical setting.

# %% [markdown]
# ### My code will print the values of equations

# %%
a = 2 
b = 9
c = a + b
print(c)
# Out:
# 11

# %% [markdown]
# - Math is important so how can we improve it?
#     - More time dedicated at school
#     - See link on articles on importance of math:
#         1. [Math in school curicullum in SAGE](https://uk.sagepub.com/sites/default/files/upm-binaries/34247_Haylock_chapter_2.pdf)__
#         2. [Importance of math](https://www.prodigygame.com/main-en/blog/why-is-math-important/)__
